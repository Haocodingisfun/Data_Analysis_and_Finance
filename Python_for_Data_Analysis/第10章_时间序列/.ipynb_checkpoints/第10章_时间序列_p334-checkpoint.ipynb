# %% [markdown]
# # 时间序列

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
close_px_all = pd.read_csv('/Users/wonderful/Desktop/stock_px.csv', parse_dates=True, index_col=0)

# %%
close_px = close_px_all[['AAPL', 'MSFT', 'XOM']]

# %%
close_px = close_px.resample('B').ffill()

# %%
close_px
# Out:
#               AAPL   MSFT    XOM
# 2003-01-02    7.40  21.11  29.22
# 2003-01-03    7.45  21.14  29.24
# 2003-01-06    7.45  21.52  29.96
# 2003-01-07    7.43  21.93  28.95
# 2003-01-08    7.28  21.31  28.83
# 2003-01-09    7.34  21.93  29.44
# 2003-01-10    7.36  21.97  29.03
# 2003-01-13    7.32  22.16  28.91
# 2003-01-14    7.30  22.39  29.17
# 2003-01-15    7.22  22.11  28.77
# 2003-01-16    7.31  21.75  28.90
# 2003-01-17    7.05  20.22  28.60
# 2003-01-20    7.05  20.22  28.60
# 2003-01-21    7.01  20.17  27.94
# 2003-01-22    6.94  20.04  27.58
# 2003-01-23    7.09  20.54  27.52
# 2003-01-24    6.90  19.59  26.93
# 2003-01-27    7.07  19.32  26.21
# 2003-01-28    7.29  19.18  26.90
# 2003-01-29    7.47  19.61  27.88
# 2003-01-30    7.16  18.95  27.37
# 2003-01-31    7.18  18.65  28.13
# 2003-02-03    7.33  19.08  28.52
# 2003-02-04    7.30  18.59  28.52
# 2003-02-05    7.22  18.45  28.11
# 2003-02-06    7.22  18.63  27.87
# 2003-02-07    7.07  18.30  27.66
# ...

# %%
# %matplotlib inline

# %%
close_px['AAPL'].plot(figsize=(21, 7))

# %%
close_px.ix['2009'].plot(figsize=(21, 7))

# %%
close_px['AAPL'].ix['01-2011':'03-2011'].plot(figsize=(21, 7))

# %%
apple_q = close_px['AAPL'].resample('Q-DEC').ffill()

# %%
apple_q.ix['2009':].plot(figsize=(21, 7))

# %% [markdown]
# # 移动窗口函数

# %%
close_px.AAPL.plot(figsize=(21, 7))
close_px.AAPL.rolling(window=250).mean().plot(figsize=(21, 7), grid=True)

# %%
apple_std250 = close_px.AAPL.rolling(window=250, min_periods=10).std()

# %%
Series.rolling?

# %%
apple_std250[5:12]
# Out:
# 2003-01-09         NaN
# 2003-01-10         NaN
# 2003-01-13         NaN
# 2003-01-14         NaN
# 2003-01-15    0.077496
# 2003-01-16    0.074760
# 2003-01-17    0.112368
# Freq: B, Name: AAPL, dtype: float64

# %%
apple_std250.plot(figsize=(21, 7))

# %%
expanding_mean = lambda x: rolling_mean(x, len(x), min_periods=1)

# %%
close_px.rolling(window=60).mean().plot(figsize=(21, 7), logy=True)

# %% [markdown]
# ## 指数加权函数
